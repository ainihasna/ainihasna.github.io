# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel(io='/content/drive/MyDrive/MSIB_PYTHON/Online Retail.xlsx', sheet_name='Online Retail')

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ## Product Analytics
#
# Quantity Distribution

# %%
ax = df['Quantity'].plot.box(
    showfliers=False,
    grid=True,
    figsize=(10, 7)
)

ax.set_ylabel('Order Quantity')
ax.set_title('Quantity Distribution')

plt.suptitle("")
plt.show()

# %% [markdown]
# Dari grafik distribution di atas dapat kita lihat bahwa  banyaknya terjual berada pada range 0-10, dan ada produk yang nilai jualnya minus yang dapat terjadi karena costumer melakukan refund atau canceled.

# %%
pd.DataFrame(df['Quantity'].describe())
# Out:
#             Quantity
# count  541909.000000
# mean        9.552250
# std       218.081158
# min    -80995.000000
# 25%         1.000000
# 50%         3.000000
# 75%        10.000000
# max     80995.000000

# %%
df.loc[df['Quantity']> 0].shape
# Out:
# (531285, 8)

# %% [markdown]
# Terdapat 531285 data yang penjualannya lebih besar dari 0.

# %%
df.shape
# Out:
# (541909, 8)

# %%
df = df.loc[df['Quantity']> 0]

# %% [markdown]
# ## Time Series Number of order
#
# Menghitung banyaknya transaksi setiap bulannya

# %%
monthly_orders_df = df.set_index('InvoiceDate')['InvoiceNo'].resample('M').nunique()

# %%
monthly_orders_df
# Out:
# InvoiceDate
# 2010-12-31    1629
# 2011-01-31    1120
# 2011-02-28    1126
# 2011-03-31    1531
# 2011-04-30    1318
# 2011-05-31    1731
# 2011-06-30    1576
# 2011-07-31    1540
# 2011-08-31    1409
# 2011-09-30    1896
# 2011-10-31    2129
# 2011-11-30    2884
# 2011-12-31     839
# Freq: M, Name: InvoiceNo, dtype: int64

# %%
ax = pd.DataFrame(monthly_orders_df.values).plot(
    grid=True,
    figsize=(10, 7),
    legend=False
)

ax.set_xlabel('date')
ax.set_ylabel('number of orders/invoices')
ax.set_title('Total Number of Orders Over Time')

plt.xticks(
    range(len(monthly_orders_df.index)),
    [x.strftime('%m.%Y') for x in monthly_orders_df.index],
    rotation=45
)

plt.show()

# %% [markdown]
# Dari grafik di atas terlihat di bulan Desember mengalami penurunan yang drastis, maka di tahapan selanjutnya kita akan mengambil data di bulan 2011-12-01. Dan kita akan melihat nilai min dan max dari data tersebut.

# %%
invoice_dates = df.loc[
    df['InvoiceDate'] >= '2011-12-01',
    'InvoiceDate'
]

# %%
print('Min date: %s/n Max Date: %s' % (invoice_dates.min(), invoice_dates.max()))
# Out:
# Min date: 2011-12-01 08:33:00/n Max Date: 2011-12-09 12:50:00

# %% [markdown]
# Dapat kita lihat bahwa ternyata di bulan Desember, datanya hanya diambil sampai tanggal 9 saja atau tidak full month.

# %%
df.loc[df['InvoiceDate'] < '2011-12-01'].shape
# Out:
# (506150, 8)

# %%
df = df.loc[df['InvoiceDate'] < '2011-12-01']

# %%
monthly_orders_df = df.set_index('InvoiceDate')['InvoiceNo'].resample('M').nunique()

# %%
monthly_orders_df
# Out:
# InvoiceDate
# 2010-12-31    1629
# 2011-01-31    1120
# 2011-02-28    1126
# 2011-03-31    1531
# 2011-04-30    1318
# 2011-05-31    1731
# 2011-06-30    1576
# 2011-07-31    1540
# 2011-08-31    1409
# 2011-09-30    1896
# 2011-10-31    2129
# 2011-11-30    2884
# Freq: M, Name: InvoiceNo, dtype: int64

# %%
ax = pd.DataFrame(monthly_orders_df.values).plot(
    grid=True,
    figsize=(10, 7),
    legend=False
)

ax.set_xlabel('date')
ax.set_ylabel('number of orders/invoices')
ax.set_title('Total Number of Orders Over Time')

plt.xticks(
    range(len(monthly_orders_df.index)),
    [x.strftime('%m.%Y') for x in monthly_orders_df.index],
    rotation=45
)

plt.show()

# %% [markdown]
# ## Time Series Revenue
#
# Melihat banyaknya penjualan di setiap bulannya

# %%
df['sales'] = df['Quantity'] * df['UnitPrice']

# %%
monthly_revenue_df = df.set_index('InvoiceDate')['sales'].resample('M').sum()

# %%
monthly_revenue_df
# Out:
# InvoiceDate
# 2010-12-31     823746.140
# 2011-01-31     691364.560
# 2011-02-28     523631.890
# 2011-03-31     717639.360
# 2011-04-30     537808.621
# 2011-05-31     770536.020
# 2011-06-30     761739.900
# 2011-07-31     719221.191
# 2011-08-31     737014.260
# 2011-09-30    1058590.172
# 2011-10-31    1154979.300
# 2011-11-30    1509496.330
# Freq: M, Name: sales, dtype: float64

# %%
ax = pd.DataFrame(monthly_revenue_df.values).plot(
    grid=True,
    figsize=(10, 7),
    legend=False
)

ax.set_xlabel('date')
ax.set_ylabel('sales')
ax.set_title('Total Revenue Over Time')

plt.xticks(
    range(len(monthly_revenue_df.index)),
    [x.strftime('%m.%Y') for x in monthly_revenue_df.index],
    rotation=45
)

plt.show()

# %% [markdown]
# ## Time Series Repeat Customers
#
# Mencari customers yang melakukan pembelian produk berulang kali

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  sales
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom  22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34

# %%
invoice_customer_df  = df.groupby(
    by = ['InvoiceNo', 'InvoiceDate']
).agg({
    'sales' : sum,
    'CustomerID' : max,
    'Country' : max
}).reset_index()

# %%
invoice_customer_df.head()
# Out:
#   InvoiceNo         InvoiceDate   sales  CustomerID         Country
# 0    536365 2010-12-01 08:26:00  139.12     17850.0  United Kingdom
# 1    536366 2010-12-01 08:28:00   22.20     17850.0  United Kingdom
# 2    536367 2010-12-01 08:34:00  278.73     13047.0  United Kingdom
# 3    536368 2010-12-01 08:34:00   70.05     13047.0  United Kingdom
# 4    536369 2010-12-01 08:35:00   17.85     13047.0  United Kingdom

# %%
monthly_repeat_customers_df = invoice_customer_df.set_index('InvoiceDate').groupby([
    pd.Grouper(freq='M'), 'CustomerID'
]).filter(lambda x: len(x) > 1).resample('M').nunique()['CustomerID']

# %% [markdown]
# Kita akan mengambil customer yang melakukan pembelian lebih dari 1 dan unik.

# %%
monthly_repeat_customers_df
# Out:
# InvoiceDate
# 2010-12-31    263
# 2011-01-31    153
# 2011-02-28    153
# 2011-03-31    203
# 2011-04-30    170
# 2011-05-31    281
# 2011-06-30    220
# 2011-07-31    227
# 2011-08-31    198
# 2011-09-30    272
# 2011-10-31    324
# 2011-11-30    541
# Freq: M, Name: CustomerID, dtype: int64

# %% [markdown]
# Kita akan mengambil seluruh custome ryang melakukan transaksi, tujuannya untuk melihat persentase banyaknya konsumen yang melakukan pembelian berulang.

# %%
monthly_unique_customers_df = df.set_index('InvoiceDate')['CustomerID'].resample('M').nunique()

# %%
monthly_unique_customers_df
# Out:
# InvoiceDate
# 2010-12-31     885
# 2011-01-31     741
# 2011-02-28     758
# 2011-03-31     974
# 2011-04-30     856
# 2011-05-31    1056
# 2011-06-30     991
# 2011-07-31     949
# 2011-08-31     935
# 2011-09-30    1266
# 2011-10-31    1364
# 2011-11-30    1665
# Freq: M, Name: CustomerID, dtype: int64

# %%
monthly_repeat_percentage = monthly_repeat_customers_df/monthly_unique_customers_df*100.0
monthly_repeat_percentage
# Out:
# InvoiceDate
# 2010-12-31    29.717514
# 2011-01-31    20.647773
# 2011-02-28    20.184697
# 2011-03-31    20.841889
# 2011-04-30    19.859813
# 2011-05-31    26.609848
# 2011-06-30    22.199798
# 2011-07-31    23.919916
# 2011-08-31    21.176471
# 2011-09-30    21.484992
# 2011-10-31    23.753666
# 2011-11-30    32.492492
# Freq: M, Name: CustomerID, dtype: float64

# %% [markdown]
# Di bulan 11 inilah banyaknya customer yang melakukan pembelian berulang

# %%
ax = pd.DataFrame(monthly_repeat_customers_df.values).plot(
    figsize = (10, 7)
)

ax = pd.DataFrame(monthly_unique_customers_df.values).plot(
    ax=ax,
    grid=True
)

ax2 = pd.DataFrame(monthly_repeat_percentage.values).plot.bar(
    ax=ax,
    grid=True,
    secondary_y=True,
    color='green',
    alpha=0.2
)

ax.set_xlabel('date')
ax.set_ylabel('number of customers')
ax.set_title('Number of ALL vs. Repeat Customers Over Time')

ax2.set_ylabel('percentage (%)')

ax.legend(['Repeat Customers', 'All Customers'])
ax2.legend(['Percentage of Repeat'], loc='upper right')

ax.set_ylim([0, monthly_unique_customers_df.values.max()+100])
ax2.set_ylim([0, 100])

plt.xticks(
    range(len(monthly_repeat_customers_df.index)),
    [x.strftime('%m.%Y') for x in monthly_repeat_customers_df.index],
    rotation=45
)

plt.show()

# %% [markdown]
# ## Revenue from Repeat Customer
#
# Pendapatan yang dihasilkan pada customer yang melakukan pembelian berulang

# %%
monthly_rev_repeat_customers_df = invoice_customer_df.set_index('InvoiceDate').groupby([
    pd.Grouper(freq='M'), 'CustomerID'
]).filter(lambda x: len(x) > 1).resample('M').sum()['sales']
# Out:
# <ipython-input-58-c475860f1f6f>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ]).filter(lambda x: len(x) > 1).resample('M').sum()['sales']

# %% [markdown]
# Kode di atas akan memfilter data berdasarkan bulan yaitu kita mengambil customer ID dan kita hitung banyaknya sales.

# %%
monthly_rev_perc_repeat_customers_df = monthly_rev_repeat_customers_df/monthly_revenue_df*100.0

# %%
monthly_rev_repeat_customers_df
# Out:
# InvoiceDate
# 2010-12-31    359170.60
# 2011-01-31    222124.00
# 2011-02-28    191229.37
# 2011-03-31    267390.48
# 2011-04-30    195474.18
# 2011-05-31    378197.04
# 2011-06-30    376307.26
# 2011-07-31    317475.00
# 2011-08-31    317134.25
# 2011-09-30    500663.36
# 2011-10-31    574006.87
# 2011-11-30    713775.85
# Freq: M, Name: sales, dtype: float64

# %%
ax = pd.DataFrame(monthly_revenue_df.values).plot(figsize=(12, 9))

pd.DataFrame(monthly_rev_repeat_customers_df.values).plot(
    ax=ax,
    grid=True,
)

ax.set_xlabel('date')
ax.set_ylabel('sales')
ax.set_title('Total Revenue vs. Revenue from Repeat Customers')

ax.legend(['Total Revenue', 'Repeat Customer Revenue'])

ax.set_ylim([0, max(monthly_revenue_df.values)+100000])

ax2 = ax.twinx()

pd.DataFrame(monthly_rev_perc_repeat_customers_df.values).plot(
    ax=ax2,
    kind='bar',
    color='g',
    alpha=0.2
)

ax2.set_ylim([0, max(monthly_rev_perc_repeat_customers_df.values)+30])
ax2.set_ylabel('percentage (%)')
ax2.legend(['Repeat Revenue Percentage'])

ax2.set_xticklabels([
    x.strftime('%m.%Y') for x in monthly_rev_perc_repeat_customers_df.index
])

plt.show()

# %% [markdown]
# Dari grafik di atas dapat kita lihat bahwa total revenue banyak dihasilkan dari repeat customers karena grafik naik drastis.

# %% [markdown]
# ## Popular Items Over Time

# %%
date_item_df = pd.DataFrame(
    df.set_index('InvoiceDate').groupby([
        pd.Grouper(freq='M'), 'StockCode'
    ])['Quantity'].sum()
)
date_item_df
# Out:
#                        Quantity
# InvoiceDate StockCode
# 2010-12-31  10002           251
#             10120            16
#             10125           154
#             10133           130
#             10135           411
# ...                         ...
# 2011-11-30  C2              173
#             DCGSSGIRL         1
#             DOT              47
#             M              3894
#             POST           1262
#
# [31701 rows x 1 columns]

# %%
# Rank items by the last month sales
last_month_sorted_df = date_item_df.loc['2011-11-30'].sort_values(
    by='Quantity', ascending=False
).reset_index()

last_month_sorted_df
# Out:
#      StockCode  Quantity
# 0        23084     14954
# 1        84826     12551
# 2        22197     12460
# 3        22086      7908
# 4       85099B      5909
# ...        ...       ...
# 2941     84549         1
# 2942     84527         1
# 2943    90082B         1
# 2944    90082D         1
# 2945    90026D         1
#
# [2946 rows x 2 columns]

# %%
# Regroup for top 5 items
date_item_df = pd.DataFrame(
    df.loc[
        df['StockCode'].isin([23084, 84826, 22197, 22086, '85099B'])
    ].set_index('InvoiceDate').groupby([
        pd.Grouper(freq='M'), 'StockCode'
    ])['Quantity'].sum()
)
date_item_df
# Out:
#                        Quantity
# InvoiceDate StockCode
# 2010-12-31  22086          2460
#             22197          2738
#             84826           366
#             85099B         2152
# 2011-01-31  22086            24
#             22197          1824
#             84826           480
#             85099B         2747
# 2011-02-28  22086             5
#             22197          2666
#             84826            66
#             85099B         3080
# 2011-03-31  22086            87
#             22197          2803
#             84826            60
#             85099B         5282
# 2011-04-30  22086            13
#             22197          1869
#             84826             1
#             85099B         2456
# 2011-05-31  22086            17
#             22197          6849
#             23084          1131
#             85099B         3621
# 2011-06-30  22086           344
#             22197          2095
#             23084          1713
# ...

# %% [markdown]
# Pada 5 produk di atas peningkatan terbesar ada di bulan 11.

# %%
trending_items_df = date_item_df.reset_index().pivot('InvoiceDate', 'StockCode').fillna(0)

trending_items_df = trending_items_df.reset_index()
trending_items_df = trending_items_df.set_index('InvoiceDate')
trending_items_df.columns = trending_items_df.columns.droplevel(0)

trending_items_df
# Out:
# <ipython-input-68-10f198223d46>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   trending_items_df = date_item_df.reset_index().pivot('InvoiceDate', 'StockCode').fillna(0)
# StockCode     22086    22197    23084    84826  85099B
# InvoiceDate
# 2010-12-31   2460.0   2738.0      0.0    366.0  2152.0
# 2011-01-31     24.0   1824.0      0.0    480.0  2747.0
# 2011-02-28      5.0   2666.0      0.0     66.0  3080.0
# 2011-03-31     87.0   2803.0      0.0     60.0  5282.0
# 2011-04-30     13.0   1869.0      0.0      1.0  2456.0
# 2011-05-31     17.0   6849.0   1131.0      0.0  3621.0
# 2011-06-30    344.0   2095.0   1713.0      4.0  3682.0
# 2011-07-31    383.0   1876.0    318.0      2.0  3129.0
# 2011-08-31    490.0   5421.0   2267.0     72.0  5502.0
# 2011-09-30   2106.0   4196.0    680.0      0.0  4401.0
# 2011-10-31   3429.0   5907.0   6348.0     11.0  5412.0
# 2011-11-30   7908.0  12460.0  14954.0  12551.0  5909.0

# %%
ax = pd.DataFrame(trending_items_df.values).plot(
  figsize=(10, 7),
  grid=True,
)

ax.set_xlabel('number of purchases')
ax.set_ylabel('date')
ax.set_title('Item Trends Over Time')

ax.legend(trending_items_df.columns, loc='upper left')

plt.xticks(
    range(len(trending_items_df.index)),
    [x.strftime('%m.%Y') for x in trending_items_df.index],
    rotation=45
)
plt.show()

# %% [markdown]
# Dari grafik di atas, kita dapat melihat bahwa produk dengan warna hijau tajam naik pada bulan 9, sedangkan produk warna merah meningkat tajam di bulan 10.
# Jadi, insight yang kita dapat adalah kita ingin meningkatkan penjualan di 5 produk itu karena 5 produk itu trend nya lebih tinggi daripada produk lain, dimana dari bulan 8-11 produk tersebut meningkat drastis yang mana produk tersebut akan memberikan keuntungan yang besar untuk penjualan kita.
